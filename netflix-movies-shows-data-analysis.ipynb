# %% [markdown]
# # Introduction
#
# Netflix is an American subscription video on-demand over-the-top streaming service. The service primarily distributes original and acquired films and television shows from various genres, and it is available internationally in multiple languages.
#
# ![](https://m.media-amazon.com/images/I/31JfJ6dXD9L.png)

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading the Dataset

# %%
netflix=pd.read_csv("/kaggle/input/netflix-titles-shows/netflix_titles.csv")

# %% [markdown]
# # First 10 values

# %%
netflix.head(10)
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
# 5  80163890  TV Show                                  Apaches
# 6  70304989    Movie                                 Automata
# 7  80164077    Movie       Fabrizio Copano: Solo pienso en mi
# 8  80117902  TV Show                             Fire Chasers
# 9  70304990    Movie                              Good People
#
#                           director  \
# 0         Richard Finn, Tim Maltby
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                 Fernando Lebrija
# 5                              NaN
# ...

# %% [markdown]
# # Shape of the dataset

# %%
netflix.shape
# Out:
# (6234, 12)

# %% [markdown]
# # Columns of the dataset

# %%
netflix.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# # Check for NULL Values

# %%
netflix.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        1969
# cast             570
# country          476
# date_added        11
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# # Check unique values

# %%
netflix.nunique()
# Out:
# show_id         6234
# type               2
# title           6172
# director        3301
# cast            5469
# country          554
# date_added      1524
# release_year      72
# rating            14
# duration         201
# listed_in        461
# description     6226
# dtype: int64

# %% [markdown]
# # Check for Duplicate values

# %%
netflix.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Make a copy of the dataset

# %%
df = netflix.copy()

# %%
df.shape
# Out:
# (6234, 12)

# %% [markdown]
# # Drop NULL values

# %%
df = df.dropna()
df.shape
# Out:
# (3774, 12)

# %% [markdown]
# # Print first 10 values

# %%
df.head(10)
# Out:
#      show_id   type                                    title  \
# 0   81145628  Movie  Norm of the North: King Sized Adventure
# 4   80125979  Movie                             #realityhigh
# 6   70304989  Movie                                 Automata
# 7   80164077  Movie       Fabrizio Copano: Solo pienso en mi
# 9   70304990  Movie                              Good People
# 11  70299204  Movie                  Kidnapping Mr. Heineken
# 19  80057969  Movie                                     Love
# 20  80060297  Movie                        Manhattan Romance
# 21  80046728  Movie                              Moonwalkers
# 23  70304988  Movie                       Stonehearst Asylum
#
#                            director  \
# 0          Richard Finn, Tim Maltby
# 4                  Fernando Lebrija
# 6                       Gabe Ibáñez
# 7   Rodrigo Toro, Francisco Schultz
# 9                 Henrik Ruben Genz
# 11                 Daniel Alfredson
# ...

# %% [markdown]
# # Convert Date Time format

# %%
import pandas as pd


# Define a function to convert date strings to datetime
def convert_to_datetime(date_str):
    try:
        return pd.to_datetime(date_str)
    except ValueError:
        return pd.NaT  # Return NaT (Not a Time) for invalid dates

# Apply the conversion function to the 'date_added' column
df['date_added'] = df['date_added'].apply(convert_to_datetime)

# Drop rows with NaT values (invalid dates)
df = df.dropna(subset=['date_added'])

# Add additional columns
df['day_added'] = df['date_added'].dt.day
df['year_added'] = df['date_added'].dt.year
df['month_added'] = df['date_added'].dt.month

# Convert to int
df['year_added'] = df['year_added'].astype(int)
df['day_added'] = df['day_added'].astype(int)
df['month_added'] = df['month_added'].astype(int)

# %%
df.head(10)
# Out:
#      show_id   type                                    title  \
# 0   81145628  Movie  Norm of the North: King Sized Adventure
# 4   80125979  Movie                             #realityhigh
# 6   70304989  Movie                                 Automata
# 7   80164077  Movie       Fabrizio Copano: Solo pienso en mi
# 9   70304990  Movie                              Good People
# 11  70299204  Movie                  Kidnapping Mr. Heineken
# 19  80057969  Movie                                     Love
# 20  80060297  Movie                        Manhattan Romance
# 21  80046728  Movie                              Moonwalkers
# 23  70304988  Movie                       Stonehearst Asylum
#
#                            director  \
# 0          Richard Finn, Tim Maltby
# 4                  Fernando Lebrija
# 6                       Gabe Ibáñez
# 7   Rodrigo Toro, Francisco Schultz
# 9                 Henrik Ruben Genz
# 11                 Daniel Alfredson
# ...

# %% [markdown]
# # Data Visualization
#
# Type: Movie and TV Shows

# %%
# Perform one-hot encoding on the 'type' column
netflix_encoded = pd.get_dummies(netflix['type'])

# Concatenate the one-hot encoded columns with the original DataFrame
netflix_encoded = pd.concat([netflix, netflix_encoded], axis=1)

# Plot the count of each category using Seaborn countplot
sns.countplot(x='type', data=netflix_encoded)
plt.title('Type')
plt.show()

# %% [markdown]
# # Rating of shows and movies

# %%
# Perform one-hot encoding on the 'rating' column
netflix_encoded = pd.get_dummies(netflix['rating'])

# Concatenate the one-hot encoded columns with the original DataFrame
netflix_encoded = pd.concat([netflix, netflix_encoded], axis=1)

# Plot the count of each category using Seaborn countplot
plt.figure(figsize=(10, 6))
sns.countplot(x='rating', data=netflix_encoded, order=netflix_encoded['rating'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Rating')
plt.show()

# %% [markdown]
# # Relation between Type and Rating

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='rating',hue='type',data=netflix)
plt.title('Relation between Type and Rating')
plt.show()

# %% [markdown]
# # Pie-chart for the Type: Movie and TV Shows

# %%
labels = ['Movie', 'TV show']
size = netflix['type'].value_counts()
colors = plt.cm.Wistia(np.linspace(0, 1, 2))
explode = [0, 0.1]
plt.rcParams['figure.figsize'] = (9, 9)
plt.pie(size,labels=labels, colors = colors, explode = explode, shadow = True, startangle = 90)
plt.title('Distribution of Type', fontsize = 25)
plt.legend()
plt.show()

# %% [markdown]
# # Pie-chart for Rating

# %%
netflix['rating'].value_counts().plot.pie(autopct='%1.2f%%',shadow=True,figsize=(18,12))
plt.show()

# %% [markdown]
# # WordCloud

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud

# %% [markdown]
# # Country

# %%
plt.subplots(figsize=(25,15))
wordcloud = WordCloud(
                          background_color='Black',
                          width=1920,
                          height=1080
                         ).generate(" ".join(df.country))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('country.png')
plt.show()

# %% [markdown]
# # Cast in the Shows

# %%
plt.subplots(figsize=(25,15))
wordcloud = WordCloud(
                          background_color='Black',
                          width=1920,
                          height=1080
                         ).generate(" ".join(df.cast))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('cast.png')
plt.show()

# %% [markdown]
# # Directors

# %%
plt.subplots(figsize=(25,15))
wordcloud = WordCloud(
                          background_color='black',
                          width=1920,
                          height=1080
                         ).generate(" ".join(df.director))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('director.png')
plt.show()

# %% [markdown]
# # Categories

# %%
plt.subplots(figsize=(25,15))
wordcloud = WordCloud(
                          background_color='Black',
                          width=1920,
                          height=1080
                         ).generate(" ".join(df.listed_in))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('category.png')
plt.show()
